# %% [markdown]
# <a href="https://www.kaggle.com/code/tanmaytripathi01/sat-score-vs-gpa-simple-linear-regression?scriptVersionId=130214148" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../input/101-simple-linear-regressioncsv/1.01. Simple linear regression.csv')
X = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1, random_state = 0)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, reg.predict(x_train), color = 'blue')
plt.title("SAT Score vs GPA (Training Model)")
plt.xlabel('SAT SCORE')
plt.ylabel('GPA')
plt.show()

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_train, reg.predict(x_train), color = 'blue')
plt.title("SAT Score vs GPA (Training Model)")
plt.xlabel('SAT SCORE')
plt.ylabel('GPA')
plt.show()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [0.00174641]
# 0.10038821971624712

# %%
print(reg.predict([[2050]]))
# Out:
# [3.68052221]
